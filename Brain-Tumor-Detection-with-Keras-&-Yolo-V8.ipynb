# %%
# Importing dependencies

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tqdm.notebook import tqdm

import tensorflow as tf
from tensorflow.keras import *
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import Callback
import keras_cv


BATCH_SIZE = 4
GLOBAL_CLIPNORM = 10.0

AUTO = tf.data.AUTOTUNE
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend

# %% [markdown]
# # <span style="color:#e74c3c;"> </span> Preprocessing

# %%
# a function for converting txt file to list
def parse_txt_annot(img_path, txt_path):
    img = cv2.imread(img_path)
    w = int(img.shape[0])
    h = int(img.shape[1])

    file_label = open(txt_path, "r")
    lines = file_label.read().split('\n')
    
    boxes = []
    classes = []
    
    if lines[0] == '':
        return img_path, classes, boxes
    else:
        for i in range(0, int(len(lines))):
            objbud=lines[i].split(' ')
            class_ = int(objbud[0])
        
            x1 = float(objbud[1])
            y1 = float(objbud[2])
            w1 = float(objbud[3])
            h1 = float(objbud[4])
        
            xmin = int((x1*w) - (w1*w)/2.0)
            ymin = int((y1*h) - (h1*h)/2.0)
            xmax = int((x1*w) + (w1*w)/2.0)
            ymax = int((y1*h) + (h1*h)/2.0)
    
            boxes.append([xmin ,ymin ,xmax ,ymax])
            classes.append(class_)
    
    return img_path, classes, boxes


# a function for creating file paths list 
def create_paths_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    
    for i in images:
        full_path.append(os.path.join(path, i))
        
    return full_path


class_ids = ['label0', 'label1', 'label2']
class_mapping = dict(zip(range(len(class_ids)), class_ids))

class_mapping
# Out:
# {0: 'label0', 1: 'label1', 2: 'label2'}

# %%
# a function for creating a dict format of files
def creating_files(img_files_paths, annot_files_paths):
    
    img_files = create_paths_list(img_files_paths)
    annot_files = create_paths_list(annot_files_paths)
    
    image_paths = []
    bbox = []
    classes = []
    
    for i in range(0,len(img_files)):
        image_path_, classes_, bbox_ = parse_txt_annot(img_files[i], annot_files[i])
        image_paths.append(image_path_)
        bbox.append(bbox_)
        classes.append(classes_)
        
    image_paths = tf.ragged.constant(image_paths)
    bbox = tf.ragged.constant(bbox)
    classes = tf.ragged.constant(classes)
    
    return image_paths, classes, bbox

# %%
# applying functions
train_img_paths, train_classes, train_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/Brain Tumor Detection/train/images', 
                                                              '/kaggle/input/medical-image-dataset-brain-tumor-detection/Brain Tumor Detection/train/labels')

valid_img_paths, valid_classes, valid_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/Brain Tumor Detection/valid/images', 
                                                              '/kaggle/input/medical-image-dataset-brain-tumor-detection/Brain Tumor Detection/valid/labels')

test_img_paths, test_classes, test_bboxes = creating_files('/kaggle/input/medical-image-dataset-brain-tumor-detection/Brain Tumor Detection/test/images', 
                                                            '/kaggle/input/medical-image-dataset-brain-tumor-detection/Brain Tumor Detection/test/labels')

# %% [markdown]
# # <span> Creating </span> Datasets

# %%
# reading and resizing images
def img_preprocessing(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels = 3)
    img = tf.cast(img, tf.float32) 
    
    return img


resizing = keras_cv.layers.JitteredResize(
    target_size=(640, 640),
    scale_factor=(0.8, 1.25),
    bounding_box_format="xyxy")

# loading dataset
def load_ds(img_paths, classes, bbox):
    img = img_preprocessing(img_paths)

    bounding_boxes = {
        "classes": tf.cast(classes, dtype=tf.float32),
        "boxes": bbox }
    
    return {"images": img, "bounding_boxes": bounding_boxes}

def dict_to_tuple(inputs):
    return inputs["images"], inputs["bounding_boxes"]

# %%
# Creating dataset loaders and tf.datasets
train_loader = tf.data.Dataset.from_tensor_slices((train_img_paths, train_classes, train_bboxes))
train_dataset = (train_loader
                 .map(load_ds, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .ragged_batch(BATCH_SIZE, drop_remainder = True)
                 .map(resizing, num_parallel_calls = AUTO)
                 .map(dict_to_tuple, num_parallel_calls = AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_img_paths, valid_classes, valid_bboxes))
valid_dataset = (valid_loader
                 .map(load_ds, num_parallel_calls = AUTO)
                 .ragged_batch(BATCH_SIZE, drop_remainder = True)
                 .map(resizing, num_parallel_calls = AUTO)
                 .map(dict_to_tuple, num_parallel_calls = AUTO)
                 .prefetch(AUTO))


test_loader = tf.data.Dataset.from_tensor_slices((test_img_paths, test_classes, test_bboxes))
test_dataset = (test_loader
                .map(load_ds, num_parallel_calls = AUTO)
                .ragged_batch(BATCH_SIZE, drop_remainder = True)
                .map(resizing, num_parallel_calls = AUTO)
                .map(dict_to_tuple, num_parallel_calls = AUTO)
                .prefetch(AUTO))

# %%
# a function to visualize samples from a dataset

def visualize_dataset(inputs, value_range, rows, cols, bounding_box_format):
    inputs = next(iter(inputs.take(1)))
    images, bounding_boxes = inputs[0], inputs[1]
    
    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=value_range,
        rows=rows,
        cols=cols,
        y_true=bounding_boxes,
        scale = 8,
        font_scale = 0.8,
        line_thickness=2,
        dpi = 100,
        bounding_box_format=bounding_box_format,
        class_mapping=class_mapping,
        true_color = (192, 57, 43))

# %%
# examples images and annotations from training daatset
visualize_dataset(train_dataset, bounding_box_format="xyxy", value_range=(0, 255), rows=2, cols=2)

# %% [markdown]
# #  YOLO V8 Model

# %%
# creating mirrored strategy

stg = tf.distribute.MirroredStrategy()

# %%
# creating pre-trained model backbone with coco weights

with stg.scope():
    backbone = keras_cv.models.YOLOV8Backbone.from_preset("yolo_v8_xs_backbone_coco")
    
    YOLOV8_model = keras_cv.models.YOLOV8Detector(num_classes=len(class_mapping),
                                              bounding_box_format="xyxy",
                                              backbone=backbone, fpn_depth=1 )

    optimizer = AdamW(learning_rate=0.0001, weight_decay=0.004, global_clipnorm = GLOBAL_CLIPNORM)

    YOLOV8_model.compile(optimizer = optimizer, classification_loss = 'binary_crossentropy', box_loss = 'ciou')
# Out:
# Attaching 'config.json' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# Attaching 'config.json' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# Attaching 'model.weights.h5' from model 'keras/yolov8/keras/yolo_v8_xs_backbone_coco/2' to your Kaggle notebook...
# /opt/conda/lib/python3.10/site-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# /opt/conda/lib/python3.10/site-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids

# %% [markdown]
# # <span> Training </span>

# %%
hist = YOLOV8_model.fit(train_dataset, validation_data = valid_dataset,  epochs = 120)
# Out:
# Epoch 1/120
# 1732/1732 [==============================] - 253s 101ms/step - loss: 704.7365 - box_loss: 5.7021 - class_loss: 699.0339 - val_loss: 52.8228 - val_box_loss: 5.1546 - val_class_loss: 47.6682
# Epoch 2/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 14.1425 - box_loss: 4.7027 - class_loss: 9.4398 - val_loss: 9.0634 - val_box_loss: 4.9753 - val_class_loss: 4.0882
# Epoch 3/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 6.7041 - box_loss: 4.4432 - class_loss: 2.2609 - val_loss: 7.0111 - val_box_loss: 4.7829 - val_class_loss: 2.2283
# Epoch 4/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 5.7629 - box_loss: 4.2796 - class_loss: 1.4832 - val_loss: 6.1853 - val_box_loss: 4.6186 - val_class_loss: 1.5667
# Epoch 5/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 5.3693 - box_loss: 4.1439 - class_loss: 1.2254 - val_loss: 5.8605 - val_box_loss: 4.4313 - val_class_loss: 1.4292
# Epoch 6/120
# 1732/1732 [==============================] - 171s 99ms/step - loss: 5.1494 - box_loss: 4.0327 - class_loss: 1.1167 - val_loss: 5.6606 - val_box_loss: 4.3736 - val_class_loss: 1.2869
# Epoch 7/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 5.0103 - box_loss: 3.9492 - class_loss: 1.0611 - val_loss: 5.5423 - val_box_loss: 4.3075 - val_class_loss: 1.2348
# Epoch 8/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 4.8579 - box_loss: 3.8490 - class_loss: 1.0089 - val_loss: 5.4220 - val_box_loss: 4.2423 - val_class_loss: 1.1797
# Epoch 9/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 4.7931 - box_loss: 3.8054 - class_loss: 0.9877 - val_loss: 5.3052 - val_box_loss: 4.1630 - val_class_loss: 1.1422
# Epoch 10/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 4.7080 - box_loss: 3.7377 - class_loss: 0.9703 - val_loss: 5.2799 - val_box_loss: 4.1592 - val_class_loss: 1.1208
# Epoch 11/120
# 1732/1732 [==============================] - 170s 98ms/step - loss: 4.6379 - box_loss: 3.6873 - class_loss: 0.9506 - val_loss: 5.2454 - val_box_loss: 4.1401 - val_class_loss: 1.1052
# Epoch 12/120
# 1732/1732 [==============================] - 170s 98ms/step - loss: 4.5706 - box_loss: 3.6370 - class_loss: 0.9336 - val_loss: 5.2229 - val_box_loss: 4.1077 - val_class_loss: 1.1152
# Epoch 13/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 4.5193 - box_loss: 3.5978 - class_loss: 0.9215 - val_loss: 5.1230 - val_box_loss: 4.0278 - val_class_loss: 1.0952
# Epoch 14/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 4.4615 - box_loss: 3.5585 - class_loss: 0.9030 - val_loss: 5.1479 - val_box_loss: 4.0694 - val_class_loss: 1.0785
# Epoch 15/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 4.4030 - box_loss: 3.5108 - class_loss: 0.8922 - val_loss: 5.1142 - val_box_loss: 4.0379 - val_class_loss: 1.0763
# Epoch 16/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 4.3411 - box_loss: 3.4666 - class_loss: 0.8745 - val_loss: 5.0286 - val_box_loss: 3.9695 - val_class_loss: 1.0592
# Epoch 17/120
# 1732/1732 [==============================] - 174s 100ms/step - loss: 4.2937 - box_loss: 3.4361 - class_loss: 0.8576 - val_loss: 5.0177 - val_box_loss: 3.9692 - val_class_loss: 1.0485
# Epoch 18/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 4.2177 - box_loss: 3.3736 - class_loss: 0.8441 - val_loss: 5.0010 - val_box_loss: 3.9787 - val_class_loss: 1.0223
# Epoch 19/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 4.2229 - box_loss: 3.3773 - class_loss: 0.8456 - val_loss: 4.9347 - val_box_loss: 3.9243 - val_class_loss: 1.0104
# Epoch 20/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 4.1278 - box_loss: 3.2982 - class_loss: 0.8296 - val_loss: 4.9168 - val_box_loss: 3.9149 - val_class_loss: 1.0019
# Epoch 21/120
# 1732/1732 [==============================] - 171s 99ms/step - loss: 4.0980 - box_loss: 3.2835 - class_loss: 0.8145 - val_loss: 4.8638 - val_box_loss: 3.8681 - val_class_loss: 0.9957
# Epoch 22/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 4.0432 - box_loss: 3.2404 - class_loss: 0.8028 - val_loss: 4.8627 - val_box_loss: 3.8734 - val_class_loss: 0.9893
# Epoch 23/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.9994 - box_loss: 3.2119 - class_loss: 0.7875 - val_loss: 4.8490 - val_box_loss: 3.8551 - val_class_loss: 0.9940
# Epoch 24/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 3.9701 - box_loss: 3.1793 - class_loss: 0.7908 - val_loss: 4.8631 - val_box_loss: 3.8820 - val_class_loss: 0.9810
# Epoch 25/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.9281 - box_loss: 3.1495 - class_loss: 0.7786 - val_loss: 4.9470 - val_box_loss: 3.9652 - val_class_loss: 0.9817
# Epoch 26/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 3.9232 - box_loss: 3.1502 - class_loss: 0.7731 - val_loss: 4.7249 - val_box_loss: 3.7652 - val_class_loss: 0.9598
# Epoch 27/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 3.8542 - box_loss: 3.0950 - class_loss: 0.7592 - val_loss: 4.7585 - val_box_loss: 3.7969 - val_class_loss: 0.9616
# Epoch 28/120
# 1732/1732 [==============================] - 171s 99ms/step - loss: 3.8414 - box_loss: 3.0811 - class_loss: 0.7604 - val_loss: 4.7758 - val_box_loss: 3.8039 - val_class_loss: 0.9718
# Epoch 29/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 3.8311 - box_loss: 3.0811 - class_loss: 0.7500 - val_loss: 4.8077 - val_box_loss: 3.8439 - val_class_loss: 0.9638
# Epoch 30/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.7669 - box_loss: 3.0290 - class_loss: 0.7379 - val_loss: 4.7236 - val_box_loss: 3.7798 - val_class_loss: 0.9438
# Epoch 31/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.7257 - box_loss: 2.9961 - class_loss: 0.7296 - val_loss: 4.7424 - val_box_loss: 3.7895 - val_class_loss: 0.9529
# Epoch 32/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 3.6934 - box_loss: 2.9774 - class_loss: 0.7159 - val_loss: 4.5930 - val_box_loss: 3.6638 - val_class_loss: 0.9293
# Epoch 33/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.6582 - box_loss: 2.9445 - class_loss: 0.7137 - val_loss: 4.7822 - val_box_loss: 3.8279 - val_class_loss: 0.9544
# Epoch 34/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.6621 - box_loss: 2.9515 - class_loss: 0.7106 - val_loss: 4.6650 - val_box_loss: 3.7354 - val_class_loss: 0.9296
# Epoch 35/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.6125 - box_loss: 2.9081 - class_loss: 0.7045 - val_loss: 4.6039 - val_box_loss: 3.6982 - val_class_loss: 0.9056
# Epoch 36/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.5891 - box_loss: 2.8920 - class_loss: 0.6971 - val_loss: 4.7232 - val_box_loss: 3.7817 - val_class_loss: 0.9416
# Epoch 37/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.5466 - box_loss: 2.8575 - class_loss: 0.6891 - val_loss: 4.6297 - val_box_loss: 3.7253 - val_class_loss: 0.9044
# Epoch 38/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.5064 - box_loss: 2.8246 - class_loss: 0.6817 - val_loss: 4.6152 - val_box_loss: 3.7088 - val_class_loss: 0.9064
# Epoch 39/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.5064 - box_loss: 2.8288 - class_loss: 0.6776 - val_loss: 4.6717 - val_box_loss: 3.7572 - val_class_loss: 0.9145
# Epoch 40/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.4659 - box_loss: 2.7977 - class_loss: 0.6681 - val_loss: 4.6329 - val_box_loss: 3.7223 - val_class_loss: 0.9106
# Epoch 41/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.4620 - box_loss: 2.7994 - class_loss: 0.6626 - val_loss: 4.5740 - val_box_loss: 3.6631 - val_class_loss: 0.9109
# Epoch 42/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 3.4279 - box_loss: 2.7677 - class_loss: 0.6601 - val_loss: 4.6759 - val_box_loss: 3.7566 - val_class_loss: 0.9193
# Epoch 43/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.4086 - box_loss: 2.7567 - class_loss: 0.6519 - val_loss: 4.5899 - val_box_loss: 3.6824 - val_class_loss: 0.9075
# Epoch 44/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.3894 - box_loss: 2.7374 - class_loss: 0.6519 - val_loss: 4.5563 - val_box_loss: 3.6670 - val_class_loss: 0.8893
# Epoch 45/120
# 1732/1732 [==============================] - 166s 96ms/step - loss: 3.3713 - box_loss: 2.7241 - class_loss: 0.6471 - val_loss: 4.5801 - val_box_loss: 3.6755 - val_class_loss: 0.9047
# Epoch 46/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.3157 - box_loss: 2.6837 - class_loss: 0.6320 - val_loss: 4.6578 - val_box_loss: 3.7513 - val_class_loss: 0.9065
# Epoch 47/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.2956 - box_loss: 2.6686 - class_loss: 0.6270 - val_loss: 4.6259 - val_box_loss: 3.7369 - val_class_loss: 0.8890
# Epoch 48/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 3.2888 - box_loss: 2.6631 - class_loss: 0.6257 - val_loss: 4.6036 - val_box_loss: 3.6997 - val_class_loss: 0.9039
# Epoch 49/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 3.2838 - box_loss: 2.6602 - class_loss: 0.6236 - val_loss: 4.6205 - val_box_loss: 3.7318 - val_class_loss: 0.8886
# Epoch 50/120
# 1732/1732 [==============================] - 170s 98ms/step - loss: 3.2892 - box_loss: 2.6637 - class_loss: 0.6256 - val_loss: 4.7359 - val_box_loss: 3.8161 - val_class_loss: 0.9198
# Epoch 51/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.2435 - box_loss: 2.6263 - class_loss: 0.6172 - val_loss: 4.5827 - val_box_loss: 3.6610 - val_class_loss: 0.9217
# Epoch 52/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.2224 - box_loss: 2.6074 - class_loss: 0.6151 - val_loss: 4.5378 - val_box_loss: 3.6533 - val_class_loss: 0.8845
# Epoch 53/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.1941 - box_loss: 2.5914 - class_loss: 0.6027 - val_loss: 4.5717 - val_box_loss: 3.6916 - val_class_loss: 0.8801
# Epoch 54/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.1554 - box_loss: 2.5647 - class_loss: 0.5907 - val_loss: 4.5375 - val_box_loss: 3.6551 - val_class_loss: 0.8823
# Epoch 55/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.1529 - box_loss: 2.5610 - class_loss: 0.5919 - val_loss: 4.5954 - val_box_loss: 3.7017 - val_class_loss: 0.8937
# Epoch 56/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.1506 - box_loss: 2.5561 - class_loss: 0.5945 - val_loss: 4.5597 - val_box_loss: 3.6662 - val_class_loss: 0.8935
# Epoch 57/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 3.1451 - box_loss: 2.5525 - class_loss: 0.5926 - val_loss: 4.4770 - val_box_loss: 3.6034 - val_class_loss: 0.8736
# Epoch 58/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 3.0966 - box_loss: 2.5179 - class_loss: 0.5787 - val_loss: 4.5385 - val_box_loss: 3.6454 - val_class_loss: 0.8930
# Epoch 59/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.1102 - box_loss: 2.5246 - class_loss: 0.5856 - val_loss: 4.5688 - val_box_loss: 3.6806 - val_class_loss: 0.8882
# Epoch 60/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.0585 - box_loss: 2.4804 - class_loss: 0.5780 - val_loss: 4.6229 - val_box_loss: 3.7211 - val_class_loss: 0.9018
# Epoch 61/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.0601 - box_loss: 2.4863 - class_loss: 0.5738 - val_loss: 4.4857 - val_box_loss: 3.6045 - val_class_loss: 0.8812
# Epoch 62/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 3.0370 - box_loss: 2.4705 - class_loss: 0.5664 - val_loss: 4.6768 - val_box_loss: 3.7695 - val_class_loss: 0.9073
# Epoch 63/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.0438 - box_loss: 2.4782 - class_loss: 0.5656 - val_loss: 4.5375 - val_box_loss: 3.6585 - val_class_loss: 0.8790
# Epoch 64/120
# 1732/1732 [==============================] - 172s 99ms/step - loss: 3.0352 - box_loss: 2.4677 - class_loss: 0.5675 - val_loss: 4.5308 - val_box_loss: 3.6593 - val_class_loss: 0.8715
# Epoch 65/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 3.0003 - box_loss: 2.4343 - class_loss: 0.5660 - val_loss: 4.4042 - val_box_loss: 3.5528 - val_class_loss: 0.8514
# Epoch 66/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 2.9496 - box_loss: 2.3977 - class_loss: 0.5520 - val_loss: 4.4437 - val_box_loss: 3.5943 - val_class_loss: 0.8494
# Epoch 67/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 2.9541 - box_loss: 2.4073 - class_loss: 0.5468 - val_loss: 4.4914 - val_box_loss: 3.6178 - val_class_loss: 0.8736
# Epoch 68/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 2.9386 - box_loss: 2.3917 - class_loss: 0.5469 - val_loss: 4.5655 - val_box_loss: 3.6737 - val_class_loss: 0.8918
# Epoch 69/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.9410 - box_loss: 2.3899 - class_loss: 0.5511 - val_loss: 4.5354 - val_box_loss: 3.6708 - val_class_loss: 0.8646
# Epoch 70/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.9351 - box_loss: 2.3930 - class_loss: 0.5421 - val_loss: 4.4776 - val_box_loss: 3.6074 - val_class_loss: 0.8703
# Epoch 71/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 2.9162 - box_loss: 2.3751 - class_loss: 0.5411 - val_loss: 4.4173 - val_box_loss: 3.5603 - val_class_loss: 0.8570
# Epoch 72/120
# 1732/1732 [==============================] - 173s 100ms/step - loss: 2.9007 - box_loss: 2.3661 - class_loss: 0.5346 - val_loss: 4.4952 - val_box_loss: 3.6312 - val_class_loss: 0.8640
# Epoch 73/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.9024 - box_loss: 2.3667 - class_loss: 0.5356 - val_loss: 4.5455 - val_box_loss: 3.6705 - val_class_loss: 0.8750
# Epoch 74/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.8693 - box_loss: 2.3396 - class_loss: 0.5297 - val_loss: 4.4822 - val_box_loss: 3.6131 - val_class_loss: 0.8691
# Epoch 75/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.8600 - box_loss: 2.3308 - class_loss: 0.5292 - val_loss: 4.5252 - val_box_loss: 3.6472 - val_class_loss: 0.8780
# Epoch 76/120
# 1732/1732 [==============================] - 171s 99ms/step - loss: 2.8407 - box_loss: 2.3135 - class_loss: 0.5272 - val_loss: 4.5545 - val_box_loss: 3.6884 - val_class_loss: 0.8661
# Epoch 77/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.8412 - box_loss: 2.3205 - class_loss: 0.5206 - val_loss: 4.3860 - val_box_loss: 3.5237 - val_class_loss: 0.8623
# Epoch 78/120
# 1732/1732 [==============================] - 171s 98ms/step - loss: 2.8236 - box_loss: 2.3039 - class_loss: 0.5197 - val_loss: 4.5696 - val_box_loss: 3.6852 - val_class_loss: 0.8844
# Epoch 79/120
# 1732/1732 [==============================] - 170s 98ms/step - loss: 2.8074 - box_loss: 2.2913 - class_loss: 0.5160 - val_loss: 4.5071 - val_box_loss: 3.6356 - val_class_loss: 0.8714
# Epoch 80/120
# 1732/1732 [==============================] - 170s 98ms/step - loss: 2.8136 - box_loss: 2.2977 - class_loss: 0.5159 - val_loss: 4.6665 - val_box_loss: 3.7601 - val_class_loss: 0.9064
# Epoch 81/120
# 1732/1732 [==============================] - 171s 99ms/step - loss: 2.7845 - box_loss: 2.2740 - class_loss: 0.5105 - val_loss: 4.5033 - val_box_loss: 3.6222 - val_class_loss: 0.8812
# Epoch 82/120
# 1732/1732 [==============================] - 171s 98ms/step - loss: 2.7602 - box_loss: 2.2567 - class_loss: 0.5035 - val_loss: 4.6031 - val_box_loss: 3.7111 - val_class_loss: 0.8920
# Epoch 83/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.7675 - box_loss: 2.2593 - class_loss: 0.5082 - val_loss: 4.4726 - val_box_loss: 3.5952 - val_class_loss: 0.8774
# Epoch 84/120
# 1732/1732 [==============================] - 170s 98ms/step - loss: 2.7396 - box_loss: 2.2415 - class_loss: 0.4980 - val_loss: 4.5685 - val_box_loss: 3.6950 - val_class_loss: 0.8735
# Epoch 85/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.7808 - box_loss: 2.2746 - class_loss: 0.5063 - val_loss: 4.4928 - val_box_loss: 3.6304 - val_class_loss: 0.8624
# Epoch 86/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.7066 - box_loss: 2.2117 - class_loss: 0.4949 - val_loss: 4.4457 - val_box_loss: 3.5845 - val_class_loss: 0.8611
# Epoch 87/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.7238 - box_loss: 2.2294 - class_loss: 0.4944 - val_loss: 4.4099 - val_box_loss: 3.5543 - val_class_loss: 0.8556
# Epoch 88/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.6997 - box_loss: 2.2056 - class_loss: 0.4941 - val_loss: 4.4720 - val_box_loss: 3.5953 - val_class_loss: 0.8767
# Epoch 89/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.7099 - box_loss: 2.2193 - class_loss: 0.4906 - val_loss: 4.4291 - val_box_loss: 3.5812 - val_class_loss: 0.8479
# Epoch 90/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.7015 - box_loss: 2.2103 - class_loss: 0.4912 - val_loss: 4.4606 - val_box_loss: 3.6058 - val_class_loss: 0.8547
# Epoch 91/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.6741 - box_loss: 2.1909 - class_loss: 0.4832 - val_loss: 4.3422 - val_box_loss: 3.5125 - val_class_loss: 0.8297
# Epoch 92/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.6920 - box_loss: 2.2065 - class_loss: 0.4855 - val_loss: 4.4295 - val_box_loss: 3.5820 - val_class_loss: 0.8475
# Epoch 93/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.6605 - box_loss: 2.1736 - class_loss: 0.4869 - val_loss: 4.4377 - val_box_loss: 3.5962 - val_class_loss: 0.8415
# Epoch 94/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.6571 - box_loss: 2.1748 - class_loss: 0.4823 - val_loss: 4.3678 - val_box_loss: 3.5264 - val_class_loss: 0.8413
# Epoch 95/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.6519 - box_loss: 2.1711 - class_loss: 0.4808 - val_loss: 4.5127 - val_box_loss: 3.6478 - val_class_loss: 0.8649
# Epoch 96/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.6187 - box_loss: 2.1442 - class_loss: 0.4745 - val_loss: 4.4671 - val_box_loss: 3.6287 - val_class_loss: 0.8384
# Epoch 97/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.6469 - box_loss: 2.1699 - class_loss: 0.4771 - val_loss: 4.4441 - val_box_loss: 3.5889 - val_class_loss: 0.8552
# Epoch 98/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.6203 - box_loss: 2.1508 - class_loss: 0.4695 - val_loss: 4.5012 - val_box_loss: 3.6258 - val_class_loss: 0.8754
# Epoch 99/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.6078 - box_loss: 2.1378 - class_loss: 0.4699 - val_loss: 4.4696 - val_box_loss: 3.6167 - val_class_loss: 0.8528
# Epoch 100/120
# 1732/1732 [==============================] - 167s 96ms/step - loss: 2.6082 - box_loss: 2.1374 - class_loss: 0.4708 - val_loss: 4.4205 - val_box_loss: 3.6002 - val_class_loss: 0.8204
# Epoch 101/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5967 - box_loss: 2.1314 - class_loss: 0.4652 - val_loss: 4.3875 - val_box_loss: 3.5384 - val_class_loss: 0.8491
# Epoch 102/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 2.5821 - box_loss: 2.1197 - class_loss: 0.4624 - val_loss: 4.4534 - val_box_loss: 3.5950 - val_class_loss: 0.8584
# Epoch 103/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5879 - box_loss: 2.1249 - class_loss: 0.4630 - val_loss: 4.5172 - val_box_loss: 3.6505 - val_class_loss: 0.8667
# Epoch 104/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 2.5729 - box_loss: 2.1082 - class_loss: 0.4647 - val_loss: 4.4248 - val_box_loss: 3.5881 - val_class_loss: 0.8367
# Epoch 105/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5349 - box_loss: 2.0780 - class_loss: 0.4569 - val_loss: 4.3923 - val_box_loss: 3.5450 - val_class_loss: 0.8473
# Epoch 106/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5553 - box_loss: 2.0939 - class_loss: 0.4614 - val_loss: 4.4573 - val_box_loss: 3.6060 - val_class_loss: 0.8512
# Epoch 107/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5631 - box_loss: 2.1031 - class_loss: 0.4600 - val_loss: 4.3623 - val_box_loss: 3.5300 - val_class_loss: 0.8324
# Epoch 108/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5217 - box_loss: 2.0697 - class_loss: 0.4520 - val_loss: 4.4293 - val_box_loss: 3.5709 - val_class_loss: 0.8584
# Epoch 109/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.5486 - box_loss: 2.0956 - class_loss: 0.4530 - val_loss: 4.3343 - val_box_loss: 3.5161 - val_class_loss: 0.8182
# Epoch 110/120
# 1732/1732 [==============================] - 167s 97ms/step - loss: 2.5357 - box_loss: 2.0793 - class_loss: 0.4564 - val_loss: 4.4057 - val_box_loss: 3.5718 - val_class_loss: 0.8338
# Epoch 111/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.5183 - box_loss: 2.0696 - class_loss: 0.4487 - val_loss: 4.3533 - val_box_loss: 3.5192 - val_class_loss: 0.8341
# Epoch 112/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.4839 - box_loss: 2.0403 - class_loss: 0.4436 - val_loss: 4.3864 - val_box_loss: 3.5434 - val_class_loss: 0.8430
# Epoch 113/120
# 1732/1732 [==============================] - 171s 98ms/step - loss: 2.5087 - box_loss: 2.0614 - class_loss: 0.4473 - val_loss: 4.4571 - val_box_loss: 3.6043 - val_class_loss: 0.8529
# Epoch 114/120
# 1732/1732 [==============================] - 171s 99ms/step - loss: 2.5040 - box_loss: 2.0553 - class_loss: 0.4487 - val_loss: 4.3906 - val_box_loss: 3.5508 - val_class_loss: 0.8398
# Epoch 115/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.5011 - box_loss: 2.0556 - class_loss: 0.4456 - val_loss: 4.5242 - val_box_loss: 3.6637 - val_class_loss: 0.8605
# Epoch 116/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.4883 - box_loss: 2.0445 - class_loss: 0.4437 - val_loss: 4.3935 - val_box_loss: 3.5548 - val_class_loss: 0.8387
# Epoch 117/120
# 1732/1732 [==============================] - 169s 97ms/step - loss: 2.4591 - box_loss: 2.0246 - class_loss: 0.4344 - val_loss: 4.4231 - val_box_loss: 3.5772 - val_class_loss: 0.8459
# Epoch 118/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.4740 - box_loss: 2.0346 - class_loss: 0.4394 - val_loss: 4.3467 - val_box_loss: 3.5213 - val_class_loss: 0.8255
# Epoch 119/120
# 1732/1732 [==============================] - 169s 98ms/step - loss: 2.4618 - box_loss: 2.0240 - class_loss: 0.4377 - val_loss: 4.4645 - val_box_loss: 3.5739 - val_class_loss: 0.8906
# Epoch 120/120
# 1732/1732 [==============================] - 168s 97ms/step - loss: 2.4352 - box_loss: 2.0046 - class_loss: 0.4305 - val_loss: 4.4464 - val_box_loss: 3.5959 - val_class_loss: 0.8505

# %% [markdown]
# # <span> Training </span> Results, Evaluation

# %%
fig, axs = plt.subplots(1,3, figsize = (18,5), dpi = 130)

axs[0].grid(linestyle="dashdot")
axs[0].set_title("Loss")
axs[0].plot(hist.history['loss'][1:])
axs[0].plot(hist.history['val_loss'][1:])
axs[0].legend(["train", "validataion"])

axs[1].grid(linestyle="dashdot")
axs[1].set_title("Box Loss")
axs[1].plot(hist.history['box_loss'])
axs[1].plot(hist.history['val_box_loss'])
axs[1].legend(["train",  "validataion"])

axs[2].grid(linestyle="dashdot")
axs[2].set_title("Class Loss")
axs[2].plot(hist.history['class_loss'][1:])
axs[2].plot(hist.history['val_class_loss'][1:])
axs[2].legend(["train",  "validataion"])

# %% [markdown]
# # <span> Test </span> Predictions

# %%
def visualize_predict_detections(model, dataset, bounding_box_format):
    images, y_true = next(iter(dataset.take(1)))
        
    y_pred = model.predict(images)
    y_pred = keras_cv.bounding_box.to_ragged(y_pred)
    
    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=(0, 255),
        bounding_box_format=bounding_box_format,
        y_true=y_true,
        y_pred=y_pred,
        true_color = (192, 57, 43),
        pred_color=(255, 235, 59),
        scale = 8,
        font_scale = 0.8,
        line_thickness=2,
        dpi = 100,
        rows=2,
        cols=2,
        show=True,
        class_mapping=class_mapping,
    )

# %%
# red -> ground true
# yellow -> prediction

visualize_predict_detections(YOLOV8_model, dataset = test_dataset, bounding_box_format="xyxy")
# Out:
# 1/1 [==============================] - 9s 9s/step
